# %%
import pandas as pd

# %%
df = pd.read_csv("Academic performance.csv")

# %%
df.head()
# Out:
#    sr               name      branch   phy  chem  maths    ai  tw         dob
# 0   2      Miguel Gibson  MECHANICAL  43.0  71.0  218.0  67.0   7   2/15/2002
# 1   3      Diane Griffin        ENTC  58.0  69.0   53.0  21.6   7    4/5/2001
# 2   4       Leigh Taylor  MECHANICAL   NaN  71.0  252.0  84.0   2    5/7/2002
# 3   5      Cecelia Arana    COMPUTER  41.0  68.0  283.0  21.4   2  12/19/2001
# 4   6  Darnell Arredondo    COMPUTER  72.0  30.0   20.0  19.1  10   5/14/2003

# %%
df.describe
# Out:
# <bound method NDFrame.describe of     sr               name      branch   phy  chem  maths    ai  tw         dob
# 0    2      Miguel Gibson  MECHANICAL  43.0  71.0  218.0  67.0   7   2/15/2002
# 1    3      Diane Griffin        ENTC  58.0  69.0   53.0  21.6   7    4/5/2001
# 2    4       Leigh Taylor  MECHANICAL   NaN  71.0  252.0  84.0   2    5/7/2002
# 3    5      Cecelia Arana    COMPUTER  41.0  68.0  283.0  21.4   2  12/19/2001
# 4    6  Darnell Arredondo    COMPUTER  72.0  30.0   20.0  19.1  10   5/14/2003
# 5    7        Twyla Brown    COMPUTER  47.0  46.6   61.6  85.0   9    4/3/2003
# 6    8       Fernando Lai    COMPUTER   NaN   4.0   68.2  33.2   2   3/28/2002
# 7    9         Tim Palmer        ENTC  35.0   NaN   51.0  62.0   4    8/7/2001
# 8   10       Rachael Gaff    COMPUTER   NaN  95.0   51.0  22.4   9   5/27/2003
# 9   11      Larry Ricardo    COMPUTER  50.0  60.0   19.0  22.9   5    6/7/2002
# ...

# %%
df.tail()
# Out:
#     sr           name      branch   phy  chem  maths    ai  tw        dob
# 7    9     Tim Palmer        ENTC  35.0   NaN   51.0  62.0   4   8/7/2001
# 8   10   Rachael Gaff    COMPUTER   NaN  95.0   51.0  22.4   9  5/27/2003
# 9   11  Larry Ricardo    COMPUTER  50.0  60.0   19.0  22.9   5   6/7/2002
# 10  12   Fermin Smith  MECHANICAL  51.0  47.2   14.0  39.0  10   6/9/2003
# 11  13   Chad Seibert  MECHANICAL  50.0  71.0   40.0  61.0   7  9/24/2001

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# dtype: bool

# %%
df.isnull()
# Out:
#        sr   name  branch    phy   chem  maths     ai     tw    dob
# 0   False  False   False  False  False  False  False  False  False
# 1   False  False   False  False  False  False  False  False  False
# 2   False  False   False   True  False  False  False  False  False
# 3   False  False   False  False  False  False  False  False  False
# 4   False  False   False  False  False  False  False  False  False
# 5   False  False   False  False  False  False  False  False  False
# 6   False  False   False   True  False  False  False  False  False
# 7   False  False   False  False   True  False  False  False  False
# 8   False  False   False   True  False  False  False  False  False
# 9   False  False   False  False  False  False  False  False  False
# 10  False  False   False  False  False  False  False  False  False
# 11  False  False   False  False  False  False  False  False  False

# %%
df.isnull().sum()
# Out:
# sr        0
# name      0
# branch    0
# phy       3
# chem      1
# maths     0
# ai        0
# tw        0
# dob       0
# dtype: int64

# %%
df['phy'].fillna(value=df['phy'].mean(),inplace=True)

# %%
df
# Out:
#     sr               name      branch        phy  chem  maths    ai  tw  \
# 0    2      Miguel Gibson  MECHANICAL  43.000000  71.0  218.0  67.0   7
# 1    3      Diane Griffin        ENTC  58.000000  69.0   53.0  21.6   7
# 2    4       Leigh Taylor  MECHANICAL  49.666667  71.0  252.0  84.0   2
# 3    5      Cecelia Arana    COMPUTER  41.000000  68.0  283.0  21.4   2
# 4    6  Darnell Arredondo    COMPUTER  72.000000  30.0   20.0  19.1  10
# 5    7        Twyla Brown    COMPUTER  47.000000  46.6   61.6  85.0   9
# 6    8       Fernando Lai    COMPUTER  49.666667   4.0   68.2  33.2   2
# 7    9         Tim Palmer        ENTC  35.000000   NaN   51.0  62.0   4
# 8   10       Rachael Gaff    COMPUTER  49.666667  95.0   51.0  22.4   9
# 9   11      Larry Ricardo    COMPUTER  50.000000  60.0   19.0  22.9   5
# 10  12       Fermin Smith  MECHANICAL  51.000000  47.2   14.0  39.0  10
# 11  13       Chad Seibert  MECHANICAL  50.000000  71.0   40.0  61.0   7
#
#            dob
# ...

# %%
df.isnull().sum()
# Out:
# sr        0
# name      0
# branch    0
# phy       0
# chem      1
# maths     0
# ai        0
# tw        0
# dob       0
# dtype: int64

# %%
import seaborn as sns

# %%
sns.boxplot(df['phy'])
# Out:
# <Axes: >

# %%
import numpy as np

# %%
df.isnull()
# Out:
#        sr   name  branch    phy   chem  maths     ai     tw    dob
# 0   False  False   False  False  False  False  False  False  False
# 1   False  False   False  False  False  False  False  False  False
# 2   False  False   False  False  False  False  False  False  False
# 3   False  False   False  False  False  False  False  False  False
# 4   False  False   False  False  False  False  False  False  False
# 5   False  False   False  False  False  False  False  False  False
# 6   False  False   False  False  False  False  False  False  False
# 7   False  False   False  False   True  False  False  False  False
# 8   False  False   False  False  False  False  False  False  False
# 9   False  False   False  False  False  False  False  False  False
# 10  False  False   False  False  False  False  False  False  False
# 11  False  False   False  False  False  False  False  False  False

# %%
df.isnull().sum()
# Out:
# sr        0
# name      0
# branch    0
# phy       0
# chem      1
# maths     0
# ai        0
# tw        0
# dob       0
# dtype: int64

# %%
df.dropna()
# Out:
#     sr               name      branch        phy  chem  maths    ai  tw  \
# 0    2      Miguel Gibson  MECHANICAL  43.000000  71.0  218.0  67.0   7
# 1    3      Diane Griffin        ENTC  58.000000  69.0   53.0  21.6   7
# 2    4       Leigh Taylor  MECHANICAL  49.666667  71.0  252.0  84.0   2
# 3    5      Cecelia Arana    COMPUTER  41.000000  68.0  283.0  21.4   2
# 4    6  Darnell Arredondo    COMPUTER  72.000000  30.0   20.0  19.1  10
# 5    7        Twyla Brown    COMPUTER  47.000000  46.6   61.6  85.0   9
# 6    8       Fernando Lai    COMPUTER  49.666667   4.0   68.2  33.2   2
# 8   10       Rachael Gaff    COMPUTER  49.666667  95.0   51.0  22.4   9
# 9   11      Larry Ricardo    COMPUTER  50.000000  60.0   19.0  22.9   5
# 10  12       Fermin Smith  MECHANICAL  51.000000  47.2   14.0  39.0  10
# 11  13       Chad Seibert  MECHANICAL  50.000000  71.0   40.0  61.0   7
#
#            dob
# 0    2/15/2002
# 1     4/5/2001
# 2     5/7/2002
# 3   12/19/2001
# 4    5/14/2003
# ...

# %%
sns.boxplot(df['phy'])
# Out:
# <Axes: >

# %%
sns.boxplot(df['chem'])
# Out:
# <Axes: >

# %%
df['phy'].describe()
# Out:
# count     6.000000
# mean     50.000000
# std       0.516398
# min      49.666667
# 25%      49.666667
# 50%      49.833333
# 75%      50.000000
# max      51.000000
# Name: phy, dtype: float64

# %%
Q1 = df['phy'].quantile(0.25)

# %%
Q1
# Out:
# 49.666666666666664

# %%
Q3 = df['phy'].quantile(0.75)

# %%
Q3
# Out:
# 50.0

# %%
IQR=Q3 -Q1

# %%
IQR
# Out:
# 0.3333333333333357

# %%
upper_limit = Q3+1.5*IQR
lower_limit = Q1 - 1.5 * IQR

# %%
upper_limit
# Out:
# 50.5

# %%
lower_limit
# Out:
# 49.16666666666666

# %%
df[(df['phy']>lower_limit)|(df['phy']<upper_limit)]
# Out:
#     sr           name      branch        phy  chem  maths    ai  tw        dob
# 2    4   Leigh Taylor  MECHANICAL  49.666667  71.0  252.0  84.0   2   5/7/2002
# 6    8   Fernando Lai    COMPUTER  49.666667   4.0   68.2  33.2   2  3/28/2002
# 8   10   Rachael Gaff    COMPUTER  49.666667  95.0   51.0  22.4   9  5/27/2003
# 9   11  Larry Ricardo    COMPUTER  50.000000  60.0   19.0  22.9   5   6/7/2002
# 10  12   Fermin Smith  MECHANICAL  51.000000  47.2   14.0  39.0  10   6/9/2003
# 11  13   Chad Seibert  MECHANICAL  50.000000  71.0   40.0  61.0   7  9/24/2001

# %%
df[(df['phy']>lower_limit)&(df['phy']<upper_limit)]
# Out:
#     sr           name      branch        phy  chem  maths    ai  tw        dob
# 2    4   Leigh Taylor  MECHANICAL  49.666667  71.0  252.0  84.0   2   5/7/2002
# 6    8   Fernando Lai    COMPUTER  49.666667   4.0   68.2  33.2   2  3/28/2002
# 8   10   Rachael Gaff    COMPUTER  49.666667  95.0   51.0  22.4   9  5/27/2003
# 9   11  Larry Ricardo    COMPUTER  50.000000  60.0   19.0  22.9   5   6/7/2002
# 11  13   Chad Seibert  MECHANICAL  50.000000  71.0   40.0  61.0   7  9/24/2001

# %%
df_no_outlier = df[(df['phy']>lower_limit)&(df['phy']<upper_limit)]

# %%
df_no_outlier
# Out:
#     sr           name      branch        phy  chem  maths    ai  tw        dob
# 2    4   Leigh Taylor  MECHANICAL  49.666667  71.0  252.0  84.0   2   5/7/2002
# 6    8   Fernando Lai    COMPUTER  49.666667   4.0   68.2  33.2   2  3/28/2002
# 8   10   Rachael Gaff    COMPUTER  49.666667  95.0   51.0  22.4   9  5/27/2003
# 9   11  Larry Ricardo    COMPUTER  50.000000  60.0   19.0  22.9   5   6/7/2002
# 11  13   Chad Seibert  MECHANICAL  50.000000  71.0   40.0  61.0   7  9/24/2001

# %%
df
# Out:
#     sr           name      branch        phy  chem  maths    ai  tw        dob
# 2    4   Leigh Taylor  MECHANICAL  49.666667  71.0  252.0  84.0   2   5/7/2002
# 6    8   Fernando Lai    COMPUTER  49.666667   4.0   68.2  33.2   2  3/28/2002
# 8   10   Rachael Gaff    COMPUTER  49.666667  95.0   51.0  22.4   9  5/27/2003
# 9   11  Larry Ricardo    COMPUTER  50.000000  60.0   19.0  22.9   5   6/7/2002
# 10  12   Fermin Smith  MECHANICAL  51.000000  47.2   14.0  39.0  10   6/9/2003
# 11  13   Chad Seibert  MECHANICAL  50.000000  71.0   40.0  61.0   7  9/24/2001

# %%
df.describe()
# Out:
#               sr        phy       chem       maths         ai         tw
# count   6.000000   6.000000   6.000000    6.000000   6.000000   6.000000
# mean    9.666667  50.000000  58.033333   74.033333  43.750000   5.833333
# std     3.265986   0.516398  30.801407   89.473609  24.257102   3.430258
# min     4.000000  49.666667   4.000000   14.000000  22.400000   2.000000
# 25%     8.500000  49.666667  50.400000   24.250000  25.475000   2.750000
# 50%    10.500000  49.833333  65.500000   45.500000  36.100000   6.000000
# 75%    11.750000  50.000000  71.000000   63.900000  55.500000   8.500000
# max    13.000000  51.000000  95.000000  252.000000  84.000000  10.000000

# %%
df.shape
# Out:
# (6, 9)

# %%
df
# Out:
#     sr           name      branch        phy  chem  maths    ai  tw        dob
# 2    4   Leigh Taylor  MECHANICAL  49.666667  71.0  252.0  84.0   2   5/7/2002
# 6    8   Fernando Lai    COMPUTER  49.666667   4.0   68.2  33.2   2  3/28/2002
# 8   10   Rachael Gaff    COMPUTER  49.666667  95.0   51.0  22.4   9  5/27/2003
# 9   11  Larry Ricardo    COMPUTER  50.000000  60.0   19.0  22.9   5   6/7/2002
# 10  12   Fermin Smith  MECHANICAL  51.000000  47.2   14.0  39.0  10   6/9/2003
# 11  13   Chad Seibert  MECHANICAL  50.000000  71.0   40.0  61.0   7  9/24/2001

# %%
import locale

# %%
df['dob'] =pd.to_datetime(df['dob'])

# %%
df
# Out:
#     sr           name      branch        phy  chem  maths    ai  tw        dob
# 2    4   Leigh Taylor  MECHANICAL  49.666667  71.0  252.0  84.0   2 2002-05-07
# 6    8   Fernando Lai    COMPUTER  49.666667   4.0   68.2  33.2   2 2002-03-28
# 8   10   Rachael Gaff    COMPUTER  49.666667  95.0   51.0  22.4   9 2003-05-27
# 9   11  Larry Ricardo    COMPUTER  50.000000  60.0   19.0  22.9   5 2002-06-07
# 10  12   Fermin Smith  MECHANICAL  51.000000  47.2   14.0  39.0  10 2003-06-09
# 11  13   Chad Seibert  MECHANICAL  50.000000  71.0   40.0  61.0   7 2001-09-24

# %%
df.info
# Out:
# <bound method DataFrame.info of     sr           name      branch        phy  chem  maths    ai  tw        dob
# 2    4   Leigh Taylor  MECHANICAL  49.666667  71.0  252.0  84.0   2 2002-05-07
# 6    8   Fernando Lai    COMPUTER  49.666667   4.0   68.2  33.2   2 2002-03-28
# 8   10   Rachael Gaff    COMPUTER  49.666667  95.0   51.0  22.4   9 2003-05-27
# 9   11  Larry Ricardo    COMPUTER  50.000000  60.0   19.0  22.9   5 2002-06-07
# 10  12   Fermin Smith  MECHANICAL  51.000000  47.2   14.0  39.0  10 2003-06-09
# 11  13   Chad Seibert  MECHANICAL  50.000000  71.0   40.0  61.0   7 2001-09-24>

# %%
df['birth month'] = df['dob'].dt.month

# %%
df
# Out:
#     sr           name      branch        phy  chem  maths    ai  tw  \
# 2    4   Leigh Taylor  MECHANICAL  49.666667  71.0  252.0  84.0   2
# 6    8   Fernando Lai    COMPUTER  49.666667   4.0   68.2  33.2   2
# 8   10   Rachael Gaff    COMPUTER  49.666667  95.0   51.0  22.4   9
# 9   11  Larry Ricardo    COMPUTER  50.000000  60.0   19.0  22.9   5
# 10  12   Fermin Smith  MECHANICAL  51.000000  47.2   14.0  39.0  10
# 11  13   Chad Seibert  MECHANICAL  50.000000  71.0   40.0  61.0   7
#
#           dob  birth month
# 2  2002-05-07            5
# 6  2002-03-28            3
# 8  2003-05-27            5
# 9  2002-06-07            6
# 10 2003-06-09            6
# 11 2001-09-24            9
